# %% [markdown]
# # Problem Framing & Target Definition
# May include:
# - task type (e.g., classification, regression, clustering)
# - target variable (if applicable)
# - prediction unit
# - evaluation metric proposal
# - stakeholder framing

# %%
# type solution here. You may create multiple cells if needed. Be sure to run every cell in this notebook before submitting your solution (so that the answers are visible).

# %% [markdown]
# # Data Inventory & Schema Audit
# May include:
# - row and column counts
# - data type audits (list of dtype)
# - semantic feature typing (continuous, count, ordinal, nominal, binary, datetime, text, ID, geo)
# - data dictionary table

# %%
# type solution here. You may create multiple cells if needed. Be sure to run every cell in this notebook before submitting your solution (so that the answers are visible).

# %% [markdown]
# # Data Quality Assessment
# May include:
# - duplicates
# - constant/quasi-constant columns
# - ID-like columns
# - type coercion errors
# - encoding glitches
# - impossible values
# - referential checks

# %%
# type solution here. You may create multiple cells if needed. Be sure to run every cell in this notebook before submitting your solution (so that the answers are visible).

# %% [markdown]
# # Missingness Analysis
# May include:
# - per column percents
# - missingness matrix/heatmap
# - missingness vs. target testing
# - imputation plan(s)

# %%
# type solution here. You may create multiple cells if needed. Be sure to run every cell in this notebook before submitting your solution (so that the answers are visible).

# %% [markdown]
# # Univariate Analysis
# May include:
# - summary stats (mean, standard deviation, quartiles, etc.)
# - skew, kurtosis
# - distribution plots
# - transformation candidates
# - frequency tables

# %%
# type solution here. You may create multiple cells if needed. Be sure to run every cell in this notebook before submitting your solution (so that the answers are visible).

# %% [markdown]
# # Target Analysis
# May include:
# - distribution for numeric target(s)
# - class balance for categorical target(s)
# - identify if resampling or transformation is needed

# %%
# type solution here. You may create multiple cells if needed. Be sure to run every cell in this notebook before submitting your solution (so that the answers are visible).

# %% [markdown]
# # Bivariate Signals vs. Target
# May include:
# - numeric to target (scatterplots)
# - categorical to target (boxplots)

# %%
# type solution here. You may create multiple cells if needed. Be sure to run every cell in this notebook before submitting your solution (so that the answers are visible).

# %% [markdown]
# # Multivariate Structure
# May include:
# - correlation matrices
# - VIF / multicollinearity
# - pairplots on top features
# - optional PCA scree
# - multivariate outliers

# %%
# type solution here. You may create multiple cells if needed. Be sure to run every cell in this notebook before submitting your solution (so that the answers are visible).

# %% [markdown]
# # Mutual Information & Leakage Screen
# May include:
# - `mutual_info_classif / mutual_info_regression` ranking
# - comparison vs. linear correlation
# - explicit linkage screen
# - tree-based permutation-importance sanity check

# %%
# type solution here. You may create multiple cells if needed. Be sure to run every cell in this notebook before submitting your solution (so that the answers are visible).

# %% [markdown]
# # SL-readiness Deliverables
# May include:
# - data card / feature dictionary with per-feature treatment plan (e.g. keep, drop, transform, encode, impute)
# - train/test/holdout split recommendation (e.g. random, stratified, etc.) with justification
# - preprocessing pipeline sketch
# - top 10 candidate predictors with evidence
# - known risks list

# %%
# type solution here. You may create multiple cells if needed. Be sure to run every cell in this notebook before submitting your solution (so that the answers are visible).
